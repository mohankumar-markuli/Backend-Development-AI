# %% [markdown]
# # LangGraph Agentic Workflow: Product Description Generator
#
# This notebook demonstrates how to build an **agentic workflow** using LangGraph.
#
# Instead of asking one LLM prompt to perform the entire task, we divide the work into smaller steps. Each step performs one responsibility, stores its result in a shared state, and passes control to the next step.
#
# ## What students will learn
#
# - What LangGraph is and why it is useful
# - How **state** carries data through a workflow
# - How **nodes** perform individual tasks
# - How **edges** control the direction of execution
# - How to build sequential, parallel, conditional, and looping workflows
# - How multiple AI steps can work together like a team of specialized agents

# %%
# !pip install -U langgraph langchain langchain-core langchain-community \
               langchain-openai langchain-experimental \
               pydantic typing-extensions
# Out:
# Requirement already satisfied: langgraph in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (1.2.10)
# Collecting langgraph
#   Downloading langgraph-1.2.11-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: langchain in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (1.3.14)
# Requirement already satisfied: langchain-core in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (1.5.3)
# Collecting langchain-core
#   Downloading langchain_core-1.5.4-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: langchain-community in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (0.4.2)
# Requirement already satisfied: langchain-openai in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (1.4.1)
# Collecting langchain-openai
#   Downloading langchain_openai-1.4.3-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langchain-experimental in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (0.4.2)
# Requirement already satisfied: pydantic in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (2.13.4)
# Requirement already satisfied: typing-extensions in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (4.16.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langgraph) (3.8.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-core) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-core) (0.10.16)
# Requirement already satisfied: packaging>=23.2.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-core) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-core) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: certifi in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.18)
# Requirement already satisfied: h11>=0.16 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-community) (2.5.1)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-community) (2.14.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.7.0)
# Requirement already satisfied: greenlet>=1 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.3)
# Requirement already satisfied: openai<3.0.0,>=2.45.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-openai) (2.53.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (0.14.0)
# Requirement already satisfied: tqdm>4 in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (4.68.4)
# Requirement already satisfied: regex in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.10)
# Requirement already satisfied: colorama in D:\GitHub\Backend-Development-AI\venv\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.45.0->langchain-openai) (0.4.6)
# Downloading langgraph-1.2.11-py3-none-any.whl (248 kB)
# Downloading langchain_core-1.5.4-py3-none-any.whl (565 kB)
#    ---------------------------------------- 0.0/565.1 kB ? eta -:--:--
#    ---------------------------------------- 565.1/565.1 kB 13.7 MB/s  0:00:00
# Downloading langchain_openai-1.4.3-py3-none-any.whl (122 kB)
# Installing collected packages: langchain-core, langchain-openai, langgraph
#
#   Attempting uninstall: langchain-core
#
#     Found existing installation: langchain-core 1.5.3
#
#     Uninstalling langchain-core-1.5.3:
#
#       Successfully uninstalled langchain-core-1.5.3
#
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#   Attempting uninstall: langchain-openai
#    ---------------------------------------- 0/3 [langchain-core]
#     Found existing installation: langchain-openai 1.4.1
#    ---------------------------------------- 0/3 [langchain-core]
#     Uninstalling langchain-openai-1.4.1:
#    ---------------------------------------- 0/3 [langchain-core]
#       Successfully uninstalled langchain-openai-1.4.1
#    ---------------------------------------- 0/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-openai]
#    ------------- -------------------------- 1/3 [langchain-openai]
#    ------------- -------------------------- 1/3 [langchain-openai]
#    ------------- -------------------------- 1/3 [langchain-openai]
#    ------------- -------------------------- 1/3 [langchain-openai]
#    ------------- -------------------------- 1/3 [langchain-openai]
#   Attempting uninstall: langgraph
#    ------------- -------------------------- 1/3 [langchain-openai]
#     Found existing installation: langgraph 1.2.10
#    ------------- -------------------------- 1/3 [langchain-openai]
#     Uninstalling langgraph-1.2.10:
#    ------------- -------------------------- 1/3 [langchain-openai]
#    -------------------------- ------------- 2/3 [langgraph]
#       Successfully uninstalled langgraph-1.2.10
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    -------------------------- ------------- 2/3 [langgraph]
#    ---------------------------------------- 3/3 [langgraph]
#
# Successfully installed langchain-core-1.5.4 langchain-openai-1.4.3 langgraph-1.2.11
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# -----------------------------------------
# Imports
# -----------------------------------------
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
import os

from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# %%
import os
import getpass

os.environ["OPENROUTER_API_KEY"] = getpass.getpass("Enter OpenRouter API Key: ")
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

# %% [markdown]
# ## 1. Shared State: The Workflow's Memory
#
# A LangGraph workflow needs a common data structure called **state**.
#
# Think of the state as a shared notebook carried through the graph. Every node can:
#
# 1. Read information already stored in the state
# 2. Perform its task
# 3. Return one or more updated state values
#
# In this example, the state begins with a product name. As the graph runs, each node adds new information such as the basic description, features, marketing message, and final description.
#
# ```text
# Initial State
#     ↓
# product_name = "Smart Water Bottle"
#     ↓
# Nodes gradually fill the remaining fields
# ```
#
# `TypedDict` describes which keys are expected in the state and the type of value stored under each key.

# %%
# -----------------------------------------
# LLM (OpenRouter)
# -----------------------------------------
llm = ChatOpenAI(
    model="openai/gpt-4o-mini",
    temperature=0.3,
    max_tokens = 300,
    openai_api_key=OPENROUTER_API_KEY,
    base_url="https://openrouter.ai/api/v1"
)

# -----------------------------------------
# Graph State
# -----------------------------------------
class State(TypedDict):
    product_name: str
    basic_description: str
    features_benefits: str
    marketing_message: str
    final_description: str

# %% [markdown]
# ## 2. Nodes: The Workers of the Graph
#
# A **node** is a Python function that performs one specific step in the workflow.
#
# Each node:
#
# - Receives the current state
# - Reads the data it needs
# - Performs an operation, such as calling an LLM
# - Returns a dictionary containing updated state fields
#
# For example:
#
# ```python
# def generate_basic_description(state: State):
#     ...
#     return {"basic_description": response.content}
# ```
#
# This node reads `product_name` and writes its result into `basic_description`.
#
# | Node name | Python function | Responsibility |
# |---|---|---|
# | `basic` | `generate_basic_description` | Creates the first product description |
# | `features` | `add_features_benefits` | Extracts features and benefits |
# | `marketing` | `create_marketing_message` | Produces persuasive marketing copy |
# | `final` | `polish_final_description` | Produces the polished final output |
#
# The node name is the label used inside the graph. The function contains the actual task logic.

# %%
# -----------------------------------------
# Nodes
# -----------------------------------------

def generate_basic_description(state: State):
    response = llm.invoke([
      SystemMessage(content="You are a helpful assistant that generates brief product descriptions."),
        HumanMessage(content=f"Write a brief description of a product named '{state['product_name']}'.")
    ])
    return {"basic_description": response.content}


def add_features_benefits(state: State):
    response = llm.invoke([
        HumanMessage(content=f"List key features and benefits of the product:\n{state['basic_description']}")
    ])
    return {"features_benefits": response.content}


def create_marketing_message(state: State):
    response = llm.invoke([
        HumanMessage(content=f"Create a compelling marketing message using:\n{state['features_benefits']}")
    ])
    return {"marketing_message": response.content}


def polish_final_description(state: State):
    response = llm.invoke([
        HumanMessage(content=f"""
Polish and finalize the product description using the marketing message below:

{state['marketing_message']}
""")
    ])
    return {"final_description": response.content}

# %% [markdown]
# ## 3. Edges: The Routes Between Nodes
#
# An **edge** tells LangGraph which node should run next.
#
# Think of nodes as cities and edges as roads connecting them.
#
# ```text
# START → basic → features → marketing → final → END
# ```
#
# ### Normal edge
#
# ```python
# workflow.add_edge("basic", "features")
# ```
#
# After `basic` finishes, LangGraph runs `features`.
#
# ### START edge
#
# ```python
# workflow.add_edge(START, "basic")
# ```
#
# `START` is the special entry point of the graph.
#
# ### END edge
#
# ```python
# workflow.add_edge("final", END)
# ```
#
# `END` tells LangGraph to stop and return the final state.
#
# ### Building the workflow
#
# - `StateGraph(State)` creates a graph using the defined state
# - `add_node()` registers a function as a graph step
# - `add_edge()` connects graph steps
# - `compile()` validates the graph and makes it executable

# %%
# -----------------------------------------
# Build LangGraph Workflow
# -----------------------------------------
def build_workflow():
    workflow = StateGraph(State)

    workflow.add_node("basic", generate_basic_description)
    workflow.add_node("features", add_features_benefits)
    workflow.add_node("marketing", create_marketing_message)
    workflow.add_node("final", polish_final_description)

    workflow.add_edge(START, "basic")
    workflow.add_edge("basic", "features")
    workflow.add_edge("features", "marketing")
    workflow.add_edge("marketing", "final")
    workflow.add_edge("final", END)

    return workflow.compile()

# %% [markdown]
# ## 4. Running the Sequential Graph
#
# `app.invoke(initial_state)` starts the graph.
#
# LangGraph then:
#
# 1. Sends the initial state to `basic`
# 2. Merges the returned update into the shared state
# 3. Follows the edge to the next node
# 4. Continues until it reaches `END`
# 5. Returns the completed state as `result`
#
# A node normally returns only the fields it changes. LangGraph merges those updates into the existing state.

# %%
# -----------------------------------------
# Run
# -----------------------------------------
if __name__ == "__main__":
    app = build_workflow()

    initial_state: State = {
        "product_name": "Smart Water Bottle",
        "basic_description": "",
        "features_benefits": "",
        "marketing_message": "",
        "final_description": "",
    }

    result = app.invoke(initial_state)

    print("\n--- BASIC DESCRIPTION ---\n")
    print(result["basic_description"])

    print("\n--- FEATURES & BENEFITS ---\n")
    print(result["features_benefits"])

    print("\n--- MARKETING MESSAGE ---\n")
    print(result["marketing_message"])

    print("\n--- FINAL DESCRIPTION ---\n")
    print(result["final_description"])
# Out:
# --- BASIC DESCRIPTION ---
#
# The Smart Water Bottle is an innovative hydration solution designed to keep you on track with your daily water intake. Featuring a sleek, ergonomic design, this bottle syncs with a mobile app to monitor your hydration levels and send reminders to drink water throughout the day. Made from durable, BPA-free materials, it includes a built-in LED indicator that lights up to alert you when it's time to hydrate. With its convenient USB rechargeable battery and leak-proof lid, the Smart Water Bottle is perfect for fitness enthusiasts, busy professionals, and anyone looking to improve their hydration habits. Stay refreshed and healthy with this essential companion!
#
# --- FEATURES & BENEFITS ---
#
# ### Key Features of the Smart Water Bottle:
#
# 1. **Mobile App Integration**: Syncs with a dedicated app to track hydration levels and set personalized goals.
# 2. **Hydration Reminders**: Sends timely notifications to remind users to drink water throughout the day.
# 3. **Ergonomic Design**: Sleek and comfortable to hold, making it easy to carry on-the-go.
# 4. **Durable, BPA-Free Materials**: Made from high-quality materials that are safe for daily use and resistant to wear and tear.
# 5. **Built-in LED Indicator**: Lights up to visually alert users when it’s time to hydrate.
# 6. **USB Rechargeable Battery**: Convenient charging option that allows for long-lasting use without frequent battery replacements.
# 7. **Leak-Proof Lid**: Ensures that the bottle is safe to carry in bags without the risk of spills.
# 8. **Versatile Use**: Ideal for fitness enthusiasts, busy professionals, and anyone looking to enhance their hydration habits.
#
# ### Benefits of the Smart Water Bottle:
#
# 1. **Promotes Healthy Hydration**: Helps users meet their daily water intake goals, contributing to overall health and well-being.
# 2. **Increases Accountability**: The app and reminders encourage users to stay consistent with their hydration habits.
# 3. **Convenient and Portable**: The lightweight design and leak-proof feature make it easy to take anywhere, from the gym to the office.
# 4. **User-Friendly Technology**: Simple
#
# --- MARKETING MESSAGE ---
#
# **Stay Hydrated, Stay Healthy with the Smart Water Bottle!**
#
# Are you ready to transform your hydration habits? Introducing the Smart Water Bottle – your ultimate companion for a healthier lifestyle!
#
# **Key Features:**
#
# - **Mobile App Integration**: Sync effortlessly with our dedicated app to track your hydration levels and set personalized goals tailored just for you.
# - **Hydration Reminders**: Never forget to drink water again! Our timely notifications keep you on track throughout the day.
# - **Ergonomic Design**: Sleek and comfortable, this bottle is designed for easy carrying, whether you're at the gym, in the office, or on the go.
# - **Durable, BPA-Free Materials**: Crafted from high-quality materials that are safe for daily use and built to withstand the rigors of your active life.
# - **Built-in LED Indicator**: A gentle light alerts you when it’s time to hydrate, ensuring you never miss a sip.
# - **USB Rechargeable Battery**: Enjoy long-lasting use with a convenient charging option – no more frequent battery replacements!
# - **Leak-Proof Lid**: Carry it in your bag without worry; our leak-proof design keeps your belongings safe and dry.
# - **Versatile Use**: Perfect for fitness enthusiasts, busy professionals, and anyone looking to enhance their hydration habits.
#
# **Benefits:**
#
# - **Promotes Healthy Hydration**: Meet your daily water intake goals and boost your overall health and well-being.
# - **Increases Accountability
#
# --- FINAL DESCRIPTION ---
#
# **Stay Hydrated, Stay Healthy with the Smart Water Bottle!**
#
# Are you ready to revolutionize your hydration habits? Meet the Smart Water Bottle – your ultimate companion for a healthier lifestyle!
#
# **Key Features:**
#
# - **Mobile App Integration**: Seamlessly sync with our dedicated app to monitor your hydration levels and set personalized goals tailored just for you.
# - **Hydration Reminders**: Say goodbye to forgetting to drink water! Our timely notifications keep you on track throughout the day.
# - **Ergonomic Design**: Sleek and comfortable, this bottle is designed for easy carrying, whether you’re at the gym, in the office, or on the go.
# - **Durable, BPA-Free Materials**: Crafted from high-quality materials that are safe for daily use and built to withstand the rigors of your active lifestyle.
# - **Built-in LED Indicator**: A gentle light alerts you when it’s time to hydrate, ensuring you never miss a sip.
# - **USB Rechargeable Battery**: Enjoy long-lasting use with a convenient charging option – no more frequent battery replacements!
# - **Leak-Proof Lid**: Carry it in your bag without worry; our leak-proof design keeps your belongings safe and dry.
# - **Versatile Use**: Ideal for fitness enthusiasts, busy professionals, and anyone looking to enhance their hydration habits.
#
# **Benefits:**
#
# - **Promotes Healthy Hydration**: Achieve your daily water intake goals and boost your overall health and well-being.
# -

# %% [markdown]
# # Advanced LangGraph Flow: Parallel Branches and a Loop
#
# The second workflow demonstrates:
#
# - **Fan-out:** one node sends work to multiple nodes
# - **Parallel processing:** independent nodes handle separate tasks
# - **Fan-in:** multiple branches join at one node
# - **Conditional edge:** the next route depends on state
# - **Loop:** execution returns to an earlier step for improvement
#
# ```text
#                          ┌→ features ─┐
# START → basic description├→ audience ─┼→ marketing → final → evaluate
#                          └→ SEO ──────┘                    │
#                                                           ├→ END
#                                                           └→ improve → evaluate
# ```

# %%
# -----------------------------------------
# Imports
# -----------------------------------------
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
import os
import random

from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# -----------------------------------------
# Load API key
# -----------------------------------------
import os
import getpass

os.environ["OPENROUTER_API_KEY"] = getpass.getpass("Enter OpenRouter API Key: ")
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

llm = ChatOpenAI(
    model="openai/gpt-4o-mini",
    temperature=0.4,
    openai_api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1"
)

# %% [markdown]
# ## 5. Parallel Nodes and Fan-Out
#
# After the basic description is created, three independent tasks begin:
#
# - Generate features and benefits
# - Identify the target audience
# - Generate SEO keywords
#
# ```python
# workflow.add_edge("basic", "features")
# workflow.add_edge("basic", "audience")
# workflow.add_edge("basic", "seo")
# ```
#
# This one-to-many branching pattern is called **fan-out**.
#
# Each branch updates a different state field:
#
# ```text
# features node  → features_benefits
# audience node  → target_audience
# seo node       → seo_keywords
# ```
#
# Parallel nodes should generally avoid writing to the same state key unless a reducer or merge strategy is configured.
#
# ## 6. Fan-In and the Merge Node
#
# The `marketing` node uses the outputs of all three branches.
#
# ```text
# features ─┐
# audience ─┼→ marketing
# SEO ──────┘
# ```
#
# This many-to-one pattern is called **fan-in**. The shared state allows the marketing node to read all three results together.

# %%
# -----------------------------------------
# State
# -----------------------------------------
class State(TypedDict):
    product_name: str
    basic_description: str
    features_benefits: str
    target_audience: str
    seo_keywords: str
    marketing_message: str
    final_description: str
    quality_score: int

# -----------------------------------------
# Nodes
# -----------------------------------------

def generate_basic_description(state: State):
    response = llm.invoke([
        SystemMessage(content="You generate short product descriptions."),
        HumanMessage(content=f"Write a brief description of '{state['product_name']}'.")
    ])
    return {"basic_description": response.content}


# ----------- PARALLEL NODES -----------

def add_features(state: State):
    response = llm.invoke(
        f"List key features and benefits:\n{state['basic_description']}"
    )
    return {"features_benefits": response.content}


def identify_audience(state: State):
    response = llm.invoke(
        f"Who is the ideal target audience for this product?\n{state['basic_description']}"
    )
    return {"target_audience": response.content}


def generate_seo_keywords(state: State):
    response = llm.invoke(
        f"Generate SEO keywords for this product:\n{state['basic_description']}"
    )
    return {"seo_keywords": response.content}


# ----------- MERGE NODE -----------

def create_marketing_message(state: State):
    combined = f"""
Features:
{state['features_benefits']}

Audience:
{state['target_audience']}

SEO:
{state['seo_keywords']}
"""
    response = llm.invoke(
        f"Create a compelling marketing message using:\n{combined}"
    )
    return {"marketing_message": response.content}

# %% [markdown]
# ## 7. Conditional Edges and Loops
#
# A normal edge always follows the same route. A **conditional edge** chooses the next route by checking the state.
#
# ```python
# lambda state: "improve" if state["quality_score"] < 6 else "end"
# ```
#
# This means:
#
# ```text
# score below 6 → improve the description
# score 6 or above → finish
# ```
#
# The improvement node connects back to evaluation:
#
# ```python
# workflow.add_edge("improve", "evaluate")
# ```
#
# This creates a loop:
#
# ```text
# evaluate → improve → evaluate
# ```
#
# Loops are useful for reflection, correction, validation, retries, and approval workflows.
#
# > This notebook uses a random quality score for demonstration. A real application could use an LLM evaluator, business rules, a validation model, or human feedback. Production loops should also have a maximum retry count.

# %%
# ----------- FINAL POLISH -----------

def polish_final_description(state: State):
    response = llm.invoke(
        f"Polish and finalize:\n{state['marketing_message']}"
    )
    return {"final_description": response.content}


# ----------- QUALITY CHECK (LOOP CONTROL) -----------

def evaluate_quality(state: State):
    """
    Simulated quality scoring.
    In real systems you'd use LLM scoring.
    """
    score = random.randint(5, 7)
    print(f"\nQuality Score: {score}")
    return {"quality_score": score}


def improve_description(state: State):
    response = llm.invoke(
        f"Improve this product description to make it more persuasive:\n{state['final_description']}"
    )
    return {"final_description": response.content}

# %% [markdown]
# ## 8. Reading the Advanced Graph Definition
#
# The graph is created in four stages:
#
# 1. Register nodes with `add_node()`
# 2. Connect `START` to the first node
# 3. Create parallel branches and merge them
# 4. Add conditional routing and the improvement loop
#
# A fixed route uses:
#
# ```python
# workflow.add_edge("marketing", "final")
# ```
#
# A dynamic route uses:
#
# ```python
# workflow.add_conditional_edges("evaluate", routing_function, route_map)
# ```
#
# The routing function inspects the state and returns a route name. The route map converts that name into a node or `END`.

# %%
# -----------------------------------------
# Build Graph
# -----------------------------------------
def build_workflow():
    workflow = StateGraph(State)
    # Nodes
    workflow.add_node("basic", generate_basic_description)
    workflow.add_node("features", add_features)
    workflow.add_node("audience", identify_audience)
    workflow.add_node("seo", generate_seo_keywords)
    workflow.add_node("marketing", create_marketing_message)
    workflow.add_node("final", polish_final_description)
    workflow.add_node("evaluate", evaluate_quality)
    workflow.add_node("improve", improve_description)
    
    # Flow
    workflow.add_edge(START, "basic")
    # ---- PARALLEL FAN OUT ----
    workflow.add_edge("basic", "features")
    workflow.add_edge("basic", "audience")
    workflow.add_edge("basic", "seo")
    # ---- FAN IN (merge) ----
    workflow.add_edge("features", "marketing")
    workflow.add_edge("audience", "marketing")
    workflow.add_edge("seo", "marketing")
    workflow.add_edge("marketing", "final")
    # ---- LOOP SECTION ----
    workflow.add_edge("final", "evaluate")
    workflow.add_conditional_edges(
        "evaluate",
        lambda state: "improve" if state["quality_score"] < 6 else "end",
        {
            "improve": "improve",
            "end": END
        }
    )
    workflow.add_edge("improve", "evaluate")
    return workflow.compile()

# %% [markdown]
# ## 9. How the State Grows
#
# For `"Smart Water Bottle"`, the state changes approximately like this:
#
# ```text
# Step 1: product_name
# Step 2: + basic_description
# Step 3: + features_benefits
#         + target_audience
#         + seo_keywords
# Step 4: + marketing_message
# Step 5: + final_description
# Step 6: + quality_score
# Step 7: improve and evaluate again, or stop
# ```
#
# The final `result` contains the complete state when the graph reaches `END`.

# %%
# -----------------------------------------
# Run
# -----------------------------------------
if __name__ == "__main__":
    app = build_workflow()

    initial_state: State = {
        "product_name": "Smart Water Bottle",
        "basic_description": "",
        "features_benefits": "",
        "target_audience": "",
        "seo_keywords": "",
        "marketing_message": "",
        "final_description": "",
        "quality_score": 0
    }

    result = app.invoke(initial_state)

    print("\nFINAL OUTPUT:\n")
    print(result["final_description"])
# Out:
# Quality Score: 7
#
# FINAL OUTPUT:
#
# ### Stay Hydrated, Stay Energized: Introducing the Smart Water Bottle!
#
# Are you ready to transform your hydration routine? Meet the **Smart Water Bottle**—your ultimate hydration companion designed for fitness enthusiasts, busy professionals, health-conscious individuals, and anyone committed to a healthy lifestyle!
#
# #### **Why Choose the Smart Water Bottle?**
#
# - **Track Your Water Intake**: Say goodbye to dehydration! Our advanced **water intake tracking** feature monitors and records your daily consumption, ensuring you effortlessly meet your hydration goals.
#
# - **Stay Connected**: With **smartphone connectivity** via Bluetooth, easily sync your water bottle with our intuitive app. Receive real-time updates on your hydration progress right at your fingertips!
#
# - **Personalized Reminders**: Life can get hectic, but staying hydrated shouldn’t be a hassle. Set **customizable reminders** that fit your schedule, so you’ll always remember to take a sip.
#
# - **Temperature Control**: Whether you crave a hot coffee or ice-cold water, our **temperature control** feature keeps your beverages just the way you like them—perfect for workouts or long commutes.
#
# - **Sleek and Ergonomic Design**: Crafted for comfort and portability, our **sleek ergonomic design** makes it easy to carry anywhere—from the gym to the office, or even on your next outdoor adventure.
#
# - **Built-in LED Display**: Stay informed with a **built-in LED display** that provides real-time updates on your water intake and beverage temperature, making hydration tracking a breeze.
#
# - **Durable and Eco-Friendly**: Made from high-quality materials, our **durable construction** ensures long-lasting use while reducing reliance on single-use plastic bottles—helping you contribute to a healthier planet.
#
# #### **Unlock Your Potential with the Smart Water Bottle!**
#
# - **Enhance Your Fitness Performance**: Hydration is key to peak performance. Whether you're hitting the gym or going for a run, our Smart Water Bottle helps you maintain optimal hydration levels for better results.
#
# - **Boost Your Focus and Energy**: Staying hydrated can significantly improve your cognitive function and energy levels throughout the day. Experience the difference with every sip!
#
# - **Motivational Gamification**: Turn hydration into a fun challenge! Our app gamifies your hydration goals, making it engaging and rewarding to drink more water.
#
# #### **Join the Hydration Revolution!**
#
# Don’t let dehydration hold you back. Whether you’re a fitness fanatic, a busy professional, a tech-savvy consumer, or a parent on the go, the Smart Water Bottle is your ideal hydration partner.
#
# **Stay hydrated, stay energized, and elevate your health with the Smart Water Bottle!**
#
# ### **Order Now and Take the First Step Towards a Healthier You!**
#
# ---
#
# **Keywords**: Smart Water Bottle, Hydration tracker, Bluetooth water bottle, Water intake monitor, Hydration reminder, Ergonomic water bottle, Fitness water bottle, Healthy drinking habits, Customizable hydration reminders, LED display water bottle, Temperature control bottle, Smart hydration solutions, Water bottle with app, Innovative water bottle, Stay hydrated, Hydration goals tracker, Water bottle for fitness, Water bottle for busy professionals, Drink more water, Health and wellness products, Smart lifestyle accessories, Portable hydration device, Eco-friendly water bottle, Stylish water bottle design, Tech-savvy water bottle.

# %% [markdown]
# ## 10. Gradio Interface
#
# The Gradio section provides a visual interface around the same compiled LangGraph workflow.
#
# When a user enters a product name:
#
# 1. Gradio creates the initial state
# 2. `app.invoke()` runs the graph
# 3. LangGraph returns the final state
# 4. Gradio displays the output produced by each node
#
# This helps students observe how a single input is transformed step by step.

# %%
# =========================================================
# GRADIO UI FOR SECOND LANGGRAPH AGENTIC WORKFLOW
# Shows output of each agent/node step
# =========================================================

# !pip install -q gradio

import gradio as gr

# Build the already-defined workflow
app = build_workflow()


def run_product_agent(product_name):
    initial_state: State = {
        "product_name": product_name,
        "basic_description": "",
        "features_benefits": "",
        "target_audience": "",
        "seo_keywords": "",
        "marketing_message": "",
        "final_description": "",
        "quality_score": 0
    }

    result = app.invoke(initial_state)

    basic = result.get("basic_description", "")
    features = result.get("features_benefits", "")
    audience = result.get("target_audience", "")
    seo = result.get("seo_keywords", "")
    marketing = result.get("marketing_message", "")
    final_description = result.get("final_description", "")
    quality_score = result.get("quality_score", "")

    process_view = f"""
# LangGraph Agentic Product Description Process

## 1. Basic Description Agent
{basic}

---

## 2. Features & Benefits Agent
{features}

---

## 3. Target Audience Agent
{audience}

---

## 4. SEO Keywords Agent
{seo}

---

## 5. Marketing Message Agent
{marketing}

---

## 6. Final Polish Agent
{final_description}

---

## 7. Quality Evaluation Agent
**Quality Score:** {quality_score}

---

## Final Output
{final_description}
"""

    return (
        basic,
        features,
        audience,
        seo,
        marketing,
        str(quality_score),
        final_description,
        process_view
    )


with gr.Blocks(title="LangGraph Product Description Agent") as demo:
    gr.Markdown("# LangGraph Product Description Agent")
    gr.Markdown(
        "Enter a product name and see how each LangGraph agent transforms it step by step."
    )

    with gr.Row():
        product_input = gr.Textbox(
            label="Product Name",
            value="Smart Water Bottle",
            placeholder="Enter product name..."
        )

    run_button = gr.Button("Generate Product Description")

    with gr.Tab("Step-by-Step Agent Outputs"):
        basic_output = gr.Textbox(
            label="1. Basic Description Agent",
            lines=6
        )

        features_output = gr.Textbox(
            label="2. Features & Benefits Agent",
            lines=8
        )

        audience_output = gr.Textbox(
            label="3. Target Audience Agent",
            lines=8
        )

        seo_output = gr.Textbox(
            label="4. SEO Keywords Agent",
            lines=6
        )

        marketing_output = gr.Textbox(
            label="5. Marketing Message Agent",
            lines=8
        )

        quality_output = gr.Textbox(
            label="6. Quality Score"
        )

        final_output = gr.Textbox(
            label="7. Final Product Description",
            lines=10
        )

    with gr.Tab("Full Process View"):
        full_process_output = gr.Markdown()

    run_button.click(
        fn=run_product_agent,
        inputs=product_input,
        outputs=[
            basic_output,
            features_output,
            audience_output,
            seo_output,
            marketing_output,
            quality_output,
            final_output,
            full_process_output
        ]
    )

demo.launch()
# Out:
# [notice] A new release of pip is available: 26.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Quality Score: 5
#
# Quality Score: 5
#
# Quality Score: 6
#
# Quality Score: 6
#
# Quality Score: 7
